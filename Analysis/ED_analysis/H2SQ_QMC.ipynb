# %%
import qmc_runner
import importlib

importlib.reload(qmc_runner)
# Out:
# <module 'qmc_runner' from 'c:\\Users\\VikasVijigiri\\Documents\\IT_QMC\\Analysis\\ED_analysis\\qmc_runner.py'>

# %%
params = {
    "betaVp": 100,
    "fangleVp": 0,
    "L": 4,
    "J2": "0.00",
    "J3": "0.00",
    "M": 1,
}

# %%
qmc_runner.run_job(params, mode="run")
# Out:
# ...
# 📂 Directory : C:\Users\VikasVijigiri\Documents\IT_QMC\files\betaVp_100\fangleVp_0\L4\J2_0.00\J3_0.00\M1
# ▶ Command   : C:\Users\VikasVijigiri\Documents\IT_QMC\files\betaVp_100\fangleVp_0\L4\J2_0.00\J3_0.00\M1\main.exe
# ...
# Lx   : 4
# Ly   : 4
# Nl   : 1
# M    : 400
# J0   : 0.05
# J1   : 0.015
# J2   : 0.00125
# J3   : 0
# h    : 0.1
# Kx   : 2.64916
# beta    : 20
# Eq steps : 100000
# Ms steps : 300000
#  Black plaquettes sites:
# 0 4 5 1
# 2 6 7 3
# 5 9 10 6
# 7 11 8 4
# 8 12 13 9
# 10 14 15 11
# 13 1 2 14
# 15 3 0 12
#  White plaquettes sites:
# 1 5 6 2
# 3 7 4 0
# 4 8 9 5
# 6 10 11 7
# 9 13 14 10
# 11 15 12 8
# 12 0 1 13
# 14 2 3 15
#  Black plaquette Neighbors
# Black Plaquette 0: 6 7 3 2
# Black Plaquette 1: 7 6 2 3
# Black Plaquette 2: 1 0 4 5
# Black Plaquette 3: 0 1 5 4
# Black Plaquette 4: 2 3 7 6
# Black Plaquette 5: 3 2 6 7
# Black Plaquette 6: 5 4 0 1
# Black Plaquette 7: 4 5 1 0
# 4 5 1 12 15 3
# 0 4 5 2 14 13
# 6 7 3 14 13 1
# 2 6 7 0 12 15
# 5 1 0 7 11 8
# ...

# %%
df_qmc = qmc_runner.show_data(params)
df_qmc.tail()
# Out:
#      Lx  Ly  Nl    M  Beta   J0   J1     J2   J3    h      enrg     enrg2  \
# 165   4   4   1  100  20.0  1.0  0.3  0.025  0.0  0.1 -0.827000  0.683929
# 166   4   4   1  100  20.0  1.0  0.3  0.025  0.0  0.1 -0.827000  0.683929
# 167   4   4   1   50  20.0  1.0  0.3  0.025  0.0  0.1 -0.828998  0.687237
# 168   4   4   1  200  20.0  1.0  0.3  0.025  0.0  0.1 -0.826000  0.682276
# 169   4   4   1  400  20.0  1.0  0.3  0.025  0.0  0.1 -0.829164  0.687681
#
#         enrg4  enrg_trans     mag_x   mag_xSq
# 165  0.467758   -0.002000  0.019997  0.000400
# 166  0.467758   -0.002000  0.019997  0.000400
# 167  0.472295   -0.003998  0.039979  0.001598
# 168  0.465500   -0.001000  0.010000  0.000100
# 169  0.473391   -0.004202  0.042023  0.018906

# %% [markdown]
# #
