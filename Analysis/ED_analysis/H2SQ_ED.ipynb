# %% [markdown]
# # s = 1/2, H2SQ model, 4 x 4 Checkerboard lattice.

# %% [markdown]
# ## Exact Diagonalization

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Import modules (Mandatory first Run)

# %%
import exact_diagonalzation_H2SQ as edb
import numpy as np
import importlib
import itertools as it
import pandas as pd

importlib.reload(edb)
pd.set_option('display.precision', 10)

# %% [markdown]
# ## (J0, J1, J2, h)

# %%
importlib.reload(edb)
Lx = 4
Ly = 4
Nl = 1
L = Lx*Ly*Nl

n = 250
sparse = True

J0 = 1.0
J1 = 0.3
J2 = 0.0
h = 0.0

###################################################################
basis_list = list(it.product([-1,1], repeat=L))
Bplqs = edb.generate_black_plaquette_indices_4_4(Lx, Ly)
#Bplqs = edb.generate_black_plaquette_indices(Lx, Ly)
edb.print_indices(Bplqs)
Wsp, Vsp = edb.H2SQ_ED(Lx, Ly, Nl, J0, J1, J2, h, Bplqs, n, sparse)
# Out:
# 0 1 4 5
# 2 3 6 7
# 5 6 9 10
# 7 4 11 8
# 8 9 12 13
# 10 11 14 15
# 13 14 1 2
# 15 12 3 0
# Hamiltonian Built -> success!

# %%
import pandas as pd

beta = 1.0
importlib.reload(edb)
df = edb.estimate_all_observables(Lx, Ly, Nl, J0, J1, J2, h, Wsp, Vsp, beta)
edb.dump_df_unique(df)

# %%
df
# Out:
#    Lx  Ly  Nl  beta   J0   J1   J2    h  n_basis_vecs          enrg  \
# 0   4   4   1   5.0  1.0  0.3  0.0  0.0           200 -0.7999963135
#
#           enrg2         enrg4       SMag_square         SMag_four  \
# 0  0.6399946546  0.4095943205  3.3615167357e-12  1.1575794032e-13
#
#               Mag_x
# 0 -1.5497086524e-14

# %%
df = pd.read_csv("ED_data.csv")

# %%
df
# Out:
#     Lx  Ly  Nl  beta   J0   J1     J2    h  n_basis_vecs          enrg  \
# 0    4   4   1  20.0  1.0  0.3  0.025  0.1            50 -0.8250228209
# 1    4   4   1  20.0  1.0  0.3  0.025  0.0            50 -0.8245503448
# 2    4   4   1  40.0  1.0  0.3  0.025  0.0            50 -0.8249916162
# 3    4   4   1   5.0  1.0  0.3  0.025  0.0            50 -0.8182754554
# 4    4   4   1   5.0  1.0  0.3  0.025  0.0           100 -0.8182745650
# 5    4   4   1   1.0  1.0  0.3  0.025  0.0           100 -0.7732508041
# 6    4   4   1   1.0  1.0  0.3  0.025  0.1           100 -0.7737074000
# 7    4   4   1   1.0  1.0  0.3  0.000  0.0           100 -0.7581134251
# 8    4   4   1   1.0  1.0  0.3  0.000  0.0            50 -0.7762380464
# 9    4   4   1   5.0  1.0  0.3  0.000  0.0            50 -0.7999980992
# 10   4   4   1  10.0  1.0  0.3  0.000  0.0            50 -0.8000000000
# 11   4   4   1  10.0  1.0  0.3  0.100  0.0            50 -0.8999664650
